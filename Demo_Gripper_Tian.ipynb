# %%
import stretch_body.robot
import time
import stretch_body.stretch_gripper 
import stretch_body.wrist_yaw
#import mpldatacursor
print("Environment Ready")
# Out:
# Environment Ready

# %%
# grasp_auto(x,y,z):
#     robot=stretch_body.robot.Robot()
#     robot.startup()
#     robot.base.translate_by(x) # x: the distance between camera and object
#     robot.push_command()
#     time.sleep(2.0)

# %%
# import stretch_body.robot
# robot=stretch_body.robot.Robot()
# robot.startup()
# robot.home()
# robot.stow() # our home function

# wrist = stretch_body.wrist_yaw.WristYaw()
# wrist.pose('side')
# robot.head.move_to('head_pan', v_r=0.6)      #rotate the camera
# robot.head.home()
# robot.head.poses('left')      #rotate the camera
# robot.head.move_to('head_pan')      #rotate the camera
# robot.base.translate_by(0.4) # base movement 
# robot.push_command()
# time.sleep(2.0) 

# robot.lift.move_by(0.3)
# robot.push_command()


# robot.base.set_rotational_velocity(v_r=0.4) #switch to velocity controller
# robot.push_command()
# time.sleep(4.0) #wait

# robot.arm.home()
# robot.lift.home()
# robot.gripper.home()

# robot.base.rotate_by(-0.2) # base movement 
# robot.push_command()
# time.sleep(2.0)
# time.sleep(10.0)
# robot.arm.move_by(-0.2)
# robot.push_command()
# time.sleep(2.0)

##########LIFT
import stretch_body.lift as lift

l=lift.Lift()
if not l.startup(threaded=False):
    exit()
l.motor.disable_sync_mode()

small_move_m=.01
large_move_m=0.25

l.push_command()
time.sleep(2.0) 
print("Done lifting")
rate='default'
req_calibration=False
stiffness=1.0

l.move_by(x_m= large_move_m, v_m=l.params['motion'][rate]['vel_m'], a_m=l.params['motion'][rate]['accel_m'],stiffness=stiffness, req_calibration=req_calibration)
l.push_command()


##########GRIPPER
gripper = stretch_body.stretch_gripper.StretchGripper()
gripper.startup()
# gripper.home()
# time.sleep(4.0)
gripper.pose('open')
print("Done gripping")

# time.sleep(4)
# robot.base.translate_by(0.2) # base movement 
# robot.push_command()
# time.sleep(2.0) 
# a_des=gripper.params['motion']['default']['accel']
# v_des=gripper.params['motion']['default']['vel']
# gripper.move_by(-10.0, v_des, a_des)
# gripper.pose('open')
# time.sleep(4.0)
# gripper.move_by(50)
# time.sleep(4.0)
# gripper.pose('close')
# gripper.stop()
# robot.lift.move_by(-0.1)
# robot.push_command()
# time.sleep(2.0)

# robot.lift.stop()
# robot.base.translate_by(-0.4) # base movement 
# robot.push_command()
# time.sleep(2.0)

# %%
# import stretch_body.robot
robot=stretch_body.robot.Robot()
robot.startup()

robot.lift.move_by(0.25)
robot.push_command()
time.sleep(2.0)
print("Done Lift")

robot.base.translate_by(0.2)
robot.push_command()
time.sleep(2.0)
print("Done Base")

gripper = stretch_body.stretch_gripper.StretchGripper()
# gripper.startup()
gripper.pose('close')
time.sleep(2.0)
print("Done gripping")

robot.base.translate_by(-0.2)
robot.push_command()
time.sleep(2.0)
print("Done Base")
# robot.home()
# robot.stow() # our home function

# wrist = stretch_body.wrist_yaw.WristYaw()
# wrist.pose('side')
# robot.head.move_to('head_pan', v_r=0.6)      #rotate the camera
# robot.head.home()
# robot.head.poses('left')      #rotate the camera
# robot.head.move_to('head_pan')      #rotate the camera
# robot.base.translate_by(0.4) # base movement 
# robot.push_command()
# time.sleep(2.0) 

# robot.lift.move_by(0.3)
# robot.push_command()


# robot.base.set_rotational_velocity(v_r=0.4) #switch to velocity controller
# robot.push_command()
# time.sleep(4.0) #wait

# robot.arm.home()
# robot.lift.home()
# robot.gripper.home()

# robot.base.rotate_by(-0.2) # base movement 
# robot.push_command()
# time.sleep(2.0)
# time.sleep(10.0)
# robot.arm.move_by(-0.2)
# robot.push_command()
# time.sleep(2.0)

##########LIFT
# import stretch_body.lift as lift

# l=lift.Lift()
# if not l.startup(threaded=False):
#     exit()
# l.motor.disable_sync_mode()

# small_move_m=.01
# large_move_m=0.25

# l.push_command()
# time.sleep(2.0) 
# print("Done lifting")
# rate='default'
# req_calibration=False
# stiffness=1.0

# l.move_by(x_m= large_move_m, v_m=l.params['motion'][rate]['vel_m'], a_m=l.params['motion'][rate]['accel_m'],stiffness=stiffness, req_calibration=req_calibration)
# l.push_command()


##########GRIPPER
# gripper = stretch_body.stretch_gripper.StretchGripper()
# gripper.startup()
# # gripper.home()
# # time.sleep(4.0)
# gripper.pose('open')
# print("Done gripping")

# time.sleep(4)
# robot.base.translate_by(0.2) # base movement 
# robot.push_command()
# time.sleep(2.0) 
# a_des=gripper.params['motion']['default']['accel']
# v_des=gripper.params['motion']['default']['vel']
# gripper.move_by(-10.0, v_des, a_des)
# gripper.pose('open')
# time.sleep(4.0)
# gripper.move_by(50)
# time.sleep(4.0)
# gripper.pose('close')
# gripper.stop()
# robot.lift.move_by(-0.1)
# robot.push_command()
# time.sleep(2.0)

# robot.lift.stop()
# robot.base.translate_by(-0.4) # base movement 
# robot.push_command()
# time.sleep(2.0)
# Out:
# Done Lift
# [WARNING] [stretch_gripper]: Dynamixel communication error on stretch_gripper:
# Done Base
# [WARNING] [stretch_gripper]: Dynamixel communication error on stretch_gripper:
# [WARNING] [stretch_gripper]: Dynamixel communication error on stretch_gripper:
# [WARNING] [stretch_gripper]: Dynamixel communication error on stretch_gripper:
# [WARNING] [stretch_gripper]: Dynamixel communication error on stretch_gripper:
# [WARNING] [stretch_gripper]: Dynamixel communication error on stretch_gripper:
# [WARNING] [stretch_gripper]: Dynamixel communication error on stretch_gripper:
# [WARNING] [stretch_gripper]: Dynamixel communication error on stretch_gripper:
# [WARNING] [stretch_gripper]: Dynamixel communication error on stretch_gripper:
# [WARNING] [stretch_gripper]: Dynamixel communication error on stretch_gripper:
# [WARNING] [stretch_gripper]: Dynamixel communication error on stretch_gripper:
# [WARNING] [stretch_gripper]: Dynamixel communication error on stretch_gripper:
# ...

# %%
# gripper = stretch_body.stretch_gripper.StretchGripper()
# gripper.startup()
# gripper.home()
# time.sleep(4.0)
gripper.pose('close')
print("Done gripping")
time.sleep(2.0)
# Out:
# [WARNING] [stretch_gripper]: Dynamixel not calibrated: stretch_gripper
# [WARNING] [stretch_gripper]: Dynamixel communication error on stretch_gripper:
# [WARNING] [stretch_gripper]: Dynamixel communication error on stretch_gripper:
# [WARNING] [stretch_gripper]: Dynamixel communication error on stretch_gripper:
# Dynamixel not calibrated: stretch_gripper
# Done gripping
# [WARNING] [stretch_gripper]: Dynamixel communication error on stretch_gripper:
# [WARNING] [stretch_gripper]: Dynamixel communication error on stretch_gripper:
# [WARNING] [stretch_gripper]: Dynamixel communication error on stretch_gripper:
# [WARNING] [stretch_gripper]: Dynamixel communication error on stretch_gripper:
# [WARNING] [stretch_gripper]: Dynamixel communication error on stretch_gripper:
# [WARNING] [stretch_gripper]: Dynamixel communication error on stretch_gripper:
# [WARNING] [stretch_gripper]: Dynamixel communication error on stretch_gripper:
# ...

# %%
gripper.stop()
# time.sleep(4) 
# l.stop()
robot.stop()
print("Done stopping")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 gripper.stop()
#       2 # time.sleep(4)
#       3 # l.stop()
#       4 robot.stop()
#
# NameError: name 'gripper' is not defined

# %%
gripper = stretch_body.stretch_gripper.StretchGripper()
gripper.startup()
# gripper.home()
# time.sleep(4.0)
gripper.pose('close')
# gripper.pose('open')
# time.sleep(4.0)
# gripper.move_by(50)
time.sleep(4.0)

# gripper.stop()

# %%
wrist = stretch_body.wrist_yaw.WristYaw()
wrist.startup()
# wrist.home()
# time.sleep(4.0)
wrist.pose('side')
time.sleep(4.0)
wrist.stop()
